# %% [markdown]
# <a href="https://colab.research.google.com/github/AzenethSH/Estadistica/blob/main/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#a)revisa si el dataset tiene valores nulos mediante df.info(), en dado caso, aplica df.dropna(inplace = True).

import pandas as pd
import numpy as np

df =pd.read_csv('https://raw.githubusercontent.com/AzenethSH/Estadistica/refs/heads/main/data.csv')
df.dropna(inplace = True)
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
#b) Obtén un mapa de calor con la matriz de correlación. Determina las variables independientes y la variable dependiente y redacta una hipótesis.

import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.corr()
plt.figure(figsize=(5, 3))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True, cbar_kws={"shrink": .8})
plt.title('Mapa de Calor de la Matriz de Correlación')
# Out:
# Text(0.5, 1.0, 'Mapa de Calor de la Matriz de Correlación')

# %%
#c) Obtén el modelo que permite relacionar las variables independientes y la variable dependiente.

X=df[['Duration', "Maxpulse"]]
Y=df['Calories']

import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()

b0, b1, b2 = modelo.params

fun = lambda x1, x2: b0 + b1 * x1 + b2 *x2

Yc = modelo.predict(x_constante)

plt.scatter(Y, Yc, color = "blue", linestyle = "--")

from sklearn.metrics import r2_score
r2 = r2_score(Y, Yc)
print(f"Coeficiente de determinación: {r2: 0.4f}\n")
# Out:
# Coeficiente de determinación:  0.8908

# %%
#d) Obtén el coeficiente de correlación e interpreta el resultado.
from sklearn.metrics import r2_score
r2 = r2_score(Y,Yc)
print(f'Coeficiente de correlacion:{r2: 0.4}/n ')
residuales = Y - Yc
# Out:
# Coeficiente de correlacion: 0.8908/n

# %%
#. e) Verifica los supuestos mediante un gráfico "y" vs "y_pred", el test de Shapiro-Wilk y el test de Breusch-Pagan. Interpreta los resultados.
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'Valor p del test de Shapiro-Wilk: {valor_p_sh: 0.4f}')
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'Valor p del test de Breusch-Pagan: {valor_p_bp: 0.4f}')
# Se rechaza Ho
# Out:
# Valor p del test de Shapiro-Wilk:  0.0000
# Valor p del test de Breusch-Pagan:  0.0000

# %%
#. f) Tomando en cuenta la información obtenida, redacta una conclusión.
# Se rechaza Ho por que el valor es muy bajo

# %% [markdown]
# El análisis del mapa de calor reveló que existe una relación notable, aunque no muy fuerte, entre las variables que se midieron (las variables independientes) y la cantidad de calorías que se quemaron. Se observó que las variables independientes influyen de manera significativa, pero no determinante, en la cantidad de calorías quemadas, según lo indicado por el mapa de calor.
#
# El modelo de regresión que se utilizó demostró que las variables 'Duration' (duración) y 'Maxpulse' (pulso máximo) son capaces de explicar un alto porcentaje (específicamente, un 89.08%) de las variaciones en la cantidad de calorías quemadas, lo cual se refleja en el coeficiente de determinación obtenido, el modelo de regresión mostró una gran capacidad predictiva, ya que las variables 'Duration' y 'Maxpulse' lograron explicar el 89.08% de la variación en las calorías quemadas, lo que indica una fuerte relación entre estas variables.
